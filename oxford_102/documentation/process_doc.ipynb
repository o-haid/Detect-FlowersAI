# %%
import scipy.io

# %%
data = scipy.io.loadmat('my_file.mat', squeeze_me=True)
variable_names = [k for k in data.keys() if not k.startswith('__')]
print("Variables in file:", variable_names)
matrix_data = data['my_variable_name']
print(matrix_data)
