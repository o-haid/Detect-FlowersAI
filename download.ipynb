# %%
import kagglehub
import shutil

# %%
cache_path = kagglehub.dataset_download("waseemalastal/the-oxford-flowers-102-dataset")
path_to_download = '/teamspace/studios/this_studio/oxford_102'
shutil.copytree(cache_path, path_to_download)
